# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
from bern_beta import bern_beta
# %matplotlib inline

# %%
prior = (0.1, 0.1)

# %% [markdown]
# ## Posterior Distribution

# %%
posterior_4H1T = bern_beta(prior, Series([1, 1, 1, 1, 0]))

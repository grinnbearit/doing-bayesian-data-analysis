# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
from bern_beta import bern_beta
# %matplotlib inline

# %% [markdown]
# ## (A)

# %%
prior = (4, 4)
posterior_H = bern_beta(prior, Series([1]))

# %% [markdown]
# ## (B)

# %%
posterior_HH = bern_beta(posterior_H, Series([1]))

# %% [markdown]
# ## (C)

# %%
posterior_HHT = bern_beta(posterior_HH, Series([0]))

# %% [markdown]
# ## (D)

# %%
posterior_THH = bern_beta(prior, Series([0, 1, 1]))

# %% [markdown]
# Yes, the posteriors in both cases are the same
